# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data load
data=pd.read_csv("/Users/Chandra Shekhar/Downloads/crime_data.csv")
data
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
# ...

# %%
data.shape
# Out:
# (230545, 15)

# %%
# Data Cleaning and Analyzing

# %%
data.isnull().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
data.describe()
# Out:
#                 AREA       Part 1-2         Crm Cd       Vict Age
# count  230545.000000  230545.000000  230545.000000  230545.000000
# mean       10.466881       1.544991     508.044629      34.451513
# std         6.225582       0.497973     240.542475      18.003355
# min         1.000000       1.000000     110.000000      -2.000000
# 25%         5.000000       1.000000     230.000000      23.000000
# 50%        11.000000       2.000000     624.000000      33.000000
# 75%        16.000000       2.000000     626.000000      46.000000
# max        21.000000       2.000000     956.000000      99.000000

# %%
d1=data.drop_duplicates()
d1
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
# ...

# %%
d1["Vict Sex"].value_counts()
# Out:
# Vict Sex
# M    110942
# F    105125
# X     13248
# H        19
# Name: count, dtype: int64

# %%
d1["Weapon Desc"].value_counts().head()
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    123034
# UNKNOWN WEAPON/OTHER WEAPON                        24526
# VERBAL THREAT                                      16937
# HAND GUN                                           14567
# SEMI-AUTOMATIC PISTOL                               5147
# Name: count, dtype: int64

# %%
d1["Status Desc"].value_counts()
# Out:
# Status Desc
# Invest Cont     136305
# Adult Other      53641
# Adult Arrest     36809
# Juv Arrest        1645
# Juv Other          932
# UNK                  2
# Name: count, dtype: int64

# %%
D=d1["Vict Age"]<18
d1.where(D).dropna()
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01  19.0      Mission       1.0   821.0
# 1       2023-01-05  2020-02-01    08:00   2.0      Rampart       2.0   812.0
# 2       2023-03-21  2020-03-15    12:00  19.0      Mission       2.0   812.0
# 3       2023-06-04  2020-07-01    12:00  20.0      Olympic       2.0   812.0
# 7       2022-01-06  2020-10-30    00:01  15.0  N Hollywood       2.0   812.0
# ...            ...         ...      ...   ...          ...       ...     ...
# 230498  2023-10-16  2023-10-16    03:10  14.0      Pacific       2.0   740.0
# 230507  2023-05-20  2023-05-20    18:20   3.0    Southwest       1.0   210.0
# 230515  2023-05-05  2023-05-05    13:00   6.0    Hollywood       2.0   627.0
# 230524  2023-11-25  2023-11-25    19:00   5.0       Harbor       2.0   627.0
# 230536  2023-05-21  2023-05-20    21:30  16.0     Foothill       2.0   624.0
#
# ...

# %%
# Data visualization

# %%
sns.countplot(data=data, x="Vict Sex")
# Out:
# <Axes: xlabel='Vict Sex', ylabel='count'>

# %%
sns.lineplot(data=d1,x='Vict Age',y='Weapon Desc')
# Out:
# <Axes: xlabel='Vict Age', ylabel='Weapon Desc'>

# %%
plt.figure(figsize=(14, 8))
sns.countplot(y='AREA NAME', data=data, order=data['AREA NAME'].value_counts().index)
plt.title('Number of Crimes by Area')
plt.xlabel('Number of Crimes')
plt.ylabel('Area Name')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x='Status Desc', data=data, order=data['Status Desc'].value_counts().index)
plt.xlabel('Status Desc')
plt.ylabel('Number of Crimes')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Vict Age'].dropna(), bins=30, kde=True)
plt.title('Distribution of Victim Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
